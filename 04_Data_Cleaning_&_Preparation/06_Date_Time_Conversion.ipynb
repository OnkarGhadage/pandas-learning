# %%
import pandas as pd

# %% [markdown]
# # Date/Time Conversion

# %%
df = pd.DataFrame({
    "OrderID": [1, 2, 3, 4],
    "OrderDate": ["2023-01-10", "2023-02-15", "2023-03-01", "2023-07-22"],
    "Amount": [5000, 6200, 4500, 7800]
})

df
# Out:
#    OrderID   OrderDate  Amount
# 0        1  2023-01-10    5000
# 1        2  2023-02-15    6200
# 2        3  2023-03-01    4500
# 3        4  2023-07-22    7800

# %% [markdown]
# ## 1. Converting date column to datetime

# %%
df.dtypes
# Out:
# OrderID       int64
# OrderDate    object
# Amount        int64
# dtype: object

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"])

# %%
df.dtypes
# Out:
# OrderID               int64
# OrderDate    datetime64[ns]
# Amount                int64
# dtype: object

# %% [markdown]
# ## 2. Extract Year, Month, Day

# %%
df["Year"] = df["OrderDate"].dt.year
df["Month"] = df["OrderDate"].dt.month
df["Day"] = df["OrderDate"].dt.day
df
# Out:
#    OrderID  OrderDate  Amount  Year  Month  Day
# 0        1 2023-01-10    5000  2023      1   10
# 1        2 2023-02-15    6200  2023      2   15
# 2        3 2023-03-01    4500  2023      3    1
# 3        4 2023-07-22    7800  2023      7   22

# %% [markdown]
# ## 3. Extracting Day name and Month name

# %%
df["Day_name"] = df["OrderDate"].dt.day_name()
df["Month_name"] = df["OrderDate"].dt.month_name()
df
# Out:
#    OrderID  OrderDate  Amount  Year  Month  Day   Day_name Month_name
# 0        1 2023-01-10    5000  2023      1   10    Tuesday    January
# 1        2 2023-02-15    6200  2023      2   15  Wednesday   February
# 2        3 2023-03-01    4500  2023      3    1  Wednesday      March
# 3        4 2023-07-22    7800  2023      7   22   Saturday       July

# %% [markdown]
# ## 4. Extract week number, Quarter

# %%
df["Week"] = df["OrderDate"].dt.isocalendar().week
df["Quarter"] = df["OrderDate"].dt.quarter
df
# Out:
#    OrderID  OrderDate  Amount  Year  Month  Day   Day_name Month_name  Week  \
# 0        1 2023-01-10    5000  2023      1   10    Tuesday    January     2
# 1        2 2023-02-15    6200  2023      2   15  Wednesday   February     7
# 2        3 2023-03-01    4500  2023      3    1  Wednesday      March     9
# 3        4 2023-07-22    7800  2023      7   22   Saturday       July    29
#
#    Quarter
# 0        1
# 1        1
# 2        1
# 3        3

# %% [markdown]
# ## 5. Check min/max date

# %%
df["OrderDate"].min()
# Out:
# Timestamp('2023-01-10 00:00:00')

# %%
df["OrderDate"].max()
# Out:
# Timestamp('2023-07-22 00:00:00')

# %% [markdown]
# ## 6. Filter by DateTime

# %%
df[df["OrderDate"] > "2023-05-02"]
# Out:
#    OrderID  OrderDate  Amount  Year  Month  Day  Day_name Month_name  Week  \
# 3        4 2023-07-22    7800  2023      7   22  Saturday       July    29
#
#    Quarter
# 3        3

# %% [markdown]
# ## 7. Custom date format conversion

# %% [markdown]
# | Format | Meaning |
# | - | - |
# | %d     | Day     |
# | %m     | Month   |
# | %Y     | Year    |
# | %H     | Hour    |
# | %M     | Minute  |
# | %S     | Second  |

# %%
df2 = pd.DataFrame({
    "Date": ["10-10-2023","20-10-2024","30-10-2025"]
})
df2
# Out:
#          Date
# 0  10-10-2023
# 1  20-10-2024
# 2  30-10-2025

# %%
pd.to_datetime(df2["Date"], format="%d-%m-%Y")
# Out:
# 0   2023-10-10
# 1   2024-10-20
# 2   2025-10-30
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ## 8. Working with timestamps

# %% [markdown]
# `"YYYY-MM-DD HH:MM:SS"`

# %%
pd.to_datetime("2023-01-10 14:30:00")
# Out:
# Timestamp('2023-01-10 14:30:00')

# %% [markdown]
# ## 9. Handle invalid dates

# %%
pd.to_datetime(df["OrderDate"], errors="coerce")
# Out:
# 0   2023-01-10
# 1   2023-02-15
# 2   2023-03-01
# 3   2023-07-22
# Name: OrderDate, dtype: datetime64[ns]

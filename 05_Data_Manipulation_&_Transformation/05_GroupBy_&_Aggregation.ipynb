# %%
import pandas as pd

# %% [markdown]
# # GroupBy & Aggregation

# %%
# Sample DataFrame
df = pd.DataFrame({
    "Employee": ["Onkar", "Amit", "Sara", "Rohit", "Neha"],
    "Department": ["IT", "IT", "HR", "IT", "HR"],
    "Salary": [50000, 65000, 55000, 70000, 48000],
    "Experience": [1, 3, 2, 5, 1]
})

df
# Out:
#   Employee Department  Salary  Experience
# 0    Onkar         IT   50000           1
# 1     Amit         IT   65000           3
# 2     Sara         HR   55000           2
# 3    Rohit         IT   70000           5
# 4     Neha         HR   48000           1

# %% [markdown]
# ## 1. What is `groupby()`? Concept

# %% [markdown]
# Split -> Apply -> Combine
# 1. Split data into groups
# 2. Apply some callculations
# 3. Combine results

# %% [markdown]
# ## 2. Basic groupby -> one column

# %% [markdown]
# Result is a Series with department as index.

# %%
# Average salary per department
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# HR    51500.000000
# IT    61666.666667
# Name: Salary, dtype: float64

# %%
# Total salary per department
df.groupby("Department")["Salary"].sum()
# Out:
# Department
# HR    103000
# IT    185000
# Name: Salary, dtype: int64

# %%
# Employee count per department
df.groupby("Department")["Employee"].count()
# Out:
# Department
# HR    2
# IT    3
# Name: Employee, dtype: int64

# %% [markdown]
# ## 3. GroupBy Multiple Aggregations — `.agg()`

# %%
df.groupby("Department")["Salary"].agg(["mean", "sum", "min", "max"])
# Out:
#                     mean     sum    min    max
# Department
# HR          51500.000000  103000  48000  55000
# IT          61666.666667  185000  50000  70000

# %% [markdown]
# Instead of calling multiple agg. function we can do...

# %%
df.groupby("Department").agg(
    avg_salary = ("Salary", "mean"),
    max_salary = ("Salary", "max"),
    min_salary = ("Salary", "min"),
    emp_count = ("Employee", "count")
)
# Out:
#               avg_salary  max_salary  min_salary  emp_count
# Department
# HR          51500.000000       55000       48000          2
# IT          61666.666667       70000       50000          3

# %% [markdown]
# ## 4. Groupby multiple columns

# %%
df.groupby(["Department", "Experience"])["Salary"].mean()
# Out:
# Department  Experience
# HR          1             48000.0
#             2             55000.0
# IT          1             50000.0
#             3             65000.0
#             5             70000.0
# Name: Salary, dtype: float64

# %%
df.groupby(["Department", "Experience"]).agg(
    emp_count = ("Employee", "count"),
    max_salary = ("Salary", "max")
)
# Out:
#                        emp_count  max_salary
# Department Experience
# HR         1                   1       48000
#            2                   1       55000
# IT         1                   1       50000
#            3                   1       65000
#            5                   1       70000

# %% [markdown]
# ## 5. GroupBy + Multiple Columns Aggregation

# %%
df.groupby("Department").agg({
    "Salary": ["mean", "sum"],
    "Experience": "mean"
})
# Out:
#                   Salary         Experience
#                     mean     sum       mean
# Department
# HR          51500.000000  103000        1.5
# IT          61666.666667  185000        3.0

# %% [markdown]
# ## 6. Reset Index After GroupBy

# %%
result = df.groupby("Department")["Salary"].mean()
result
# Out:
# Department
# HR    51500.000000
# IT    61666.666667
# Name: Salary, dtype: float64

# %%
result.reset_index()
# Out:
#   Department        Salary
# 0         HR  51500.000000
# 1         IT  61666.666667

# %% [markdown]
# ## 7. `transform()` — Return Same Shape as Original Data

# %%
df["Dept_Avg_Salary"] = df.groupby("Department")["Salary"].transform("mean")

# %%
df
# Out:
#   Employee Department  Salary  Experience  Dept_Avg_Salary
# 0    Onkar         IT   50000           1     61666.666667
# 1     Amit         IT   65000           3     61666.666667
# 2     Sara         HR   55000           2     51500.000000
# 3    Rohit         IT   70000           5     61666.666667
# 4     Neha         HR   48000           1     51500.000000

# %% [markdown]
# ## Difference between `agg()` and `transform()`
#
# | Feature     | `agg()` | `transform()`    |
# | - | - | - |
# | Output rows | Reduced | Same as original |
# | Use case    | Summary | Feature creation |
# | Shape       | Smaller | Same             |

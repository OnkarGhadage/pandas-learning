# %% [markdown]
# # Install & Import Pandas

# %% [markdown]
# ## What is Pandas?
# Pan - Panel, Da- Data -> Panda

# %% [markdown]
# ## Installing pandas

# %%
pip install pandas

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# 'pd' is short name for pandas

# %% [markdown]
# ## Printing version of pandas

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ## Example
# Just to verify pandas is working

# %%
df = pd.DataFrame({
    "Name" : ["ABC","XYZ"],
    "Age" : [21,25],
})

print(df)
# Out:
#   Name  Age
# 0  ABC   21
# 1  XYZ   25
